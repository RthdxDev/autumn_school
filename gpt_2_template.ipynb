# %%
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd

# %%
df = pd.read_csv('/home/matta/repos/autumn_school/data/russianPoetryWithTheme.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1800114821.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/home/matta/repos/autumn_school/data/russianPoetryWithTheme.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i,ch in enumerate(chars)} # string to index
itos = {i: ch for i,ch in enumerate(chars)} # index to string
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-555145585.py in <cell line: 0>()
#       2 #     text = f.read()
#       3
# ----> 4 chars = sorted(list(set(text)))
#       5 vocab_size = len(chars)
#       6 stoi = {ch: i for i,ch in enumerate(chars)} # string to index
#
# NameError: name 'text' is not defined

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        # query, key, value
        # нижнетреугольная матрица
        # drop out

    def forward(self, x):
        out = x
        return out

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        # проход по головам
        # склеиванием результатов голов
        # drop out

    def forward(self, x):
        out = x
        return out

# %%
class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        # линейный слой, функция активации, droupout

    def forward(self, x):
        return x

# %%
class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        super().__init__()
        # этапы как с картинки трансформера

    def forward(self, x):
        return x

# %%
class GPTLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        # и так далее:
        # эмбеддинги, блоки трансформера, верхняя голова

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape # B батчей в каждом T токенов(символов)

        tok_emb = self.token_embedding_table(idx) # (B,T,C) # каждый токен стал представляться вектором-эмбедингом длины C
        # и так далее

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            # генерируем следующий токен по предыдущему
        return idx
