# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
cur_dir = './'

# %%
post_gelu_ne_train_loss = torch.load(cur_dir + 'log/post-ln_gelu_no-PE_train_loss_history.pt', map_location=device)
post_gelu_ne_val_loss = torch.load(cur_dir + 'log/post-ln_gelu_no-PE_val_loss_history.pt', map_location=device)
post_gelu_ne_train_perplexity = torch.load(cur_dir + 'log/post-ln_gelu_no-PE_train_perplexity_history.pt', map_location=device)
post_gelu_ne_val_perplexity = torch.load(cur_dir + 'log/post-ln_gelu_no-PE_val_perplexity_history.pt', map_location=device)

post_relu_ne_train_loss = torch.load(cur_dir + 'log/post-ln_relu_no-PE_train_loss_history.pt', map_location=device)
post_relu_ne_val_loss = torch.load(cur_dir + 'log/post-ln_relu_no-PE_val_loss_history.pt', map_location=device)
post_relu_ne_train_perplexity = torch.load(cur_dir + 'log/post-ln_relu_no-PE_train_perplexity_history.pt', map_location=device)
post_relu_ne_val_perplexity = torch.load(cur_dir + 'log/post-ln_relu_no-PE_val_perplexity_history.pt', map_location=device)

pre_relu_ne_train_loss = torch.load(cur_dir + 'log/pre-ln_relu_no-PE_train_loss_history.pt', map_location=device)
pre_relu_ne_val_loss = torch.load(cur_dir + 'log/pre-ln_relu_no-PE_val_loss_history.pt', map_location=device)
pre_relu_ne_train_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_no-PE_train_perplexity_history.pt', map_location=device)
pre_relu_ne_val_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_no-PE_val_perplexity_history.pt', map_location=device)

post_glu_ne_train_loss = torch.load(cur_dir + 'log/post-ln_glu_no-PE_train_loss_history.pt', map_location=device)
post_glu_ne_val_loss = torch.load(cur_dir + 'log/post-ln_glu_no-PE_val_loss_history.pt', map_location=device)
post_glu_ne_train_perplexity = torch.load(cur_dir + 'log/post-ln_glu_no-PE_train_perplexity_history.pt', map_location=device)
post_glu_ne_val_perplexity = torch.load(cur_dir + 'log/post-ln_glu_no-PE_val_perplexity_history.pt', map_location=device)

post_relu_pe_sin_train_loss = torch.load(cur_dir + 'log/post-ln_relu_sin-pe_train_loss_history.pt', map_location=device)
post_relu_pe_sin_val_loss = torch.load(cur_dir + 'log/post-ln_relu_sin-pe_val_loss_history.pt', map_location=device)
post_relu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/post-ln_relu_sin-pe_train_perplexity_history.pt', map_location=device)
post_relu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/post-ln_relu_sin-pe_val_perplexity_history.pt', map_location=device)

pre_glu_ne_train_loss = torch.load(cur_dir + 'log/pre-ln_glu_no-PE_train_loss_history.pt', map_location=device)
pre_glu_ne_val_loss = torch.load(cur_dir + 'log/pre-ln_glu_no-PE_val_loss_history.pt', map_location=device)
pre_glu_ne_train_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_no-PE_train_perplexity_history.pt', map_location=device)
pre_glu_ne_val_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_no-PE_val_perplexity_history.pt', map_location=device)

pre_glu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_glu_sin-pe_train_loss_history.pt', map_location=device)
pre_glu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_glu_sin-pe_val_loss_history.pt', map_location=device)
pre_glu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_glu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_sin-pe_val_perplexity_history.pt', map_location=device)

pre_glu_pe_learned_train_loss = torch.load(cur_dir + 'log/pre-ln_glu_learned-pe_train_loss_history.pt', map_location=device)
pre_glu_pe_learned_val_loss = torch.load(cur_dir + 'log/pre-ln_glu_learned-pe_val_loss_history.pt', map_location=device)
pre_glu_pe_learned_train_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_learned-pe_train_perplexity_history.pt', map_location=device)
pre_glu_pe_learned_val_perplexity = torch.load(cur_dir + 'log/pre-ln_glu_learned-pe_val_perplexity_history.pt', map_location=device)

pre_relu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_relu_sin-pe_train_loss_history.pt', map_location=device)
pre_relu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_relu_sin-pe_val_loss_history.pt', map_location=device)
pre_relu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_relu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_sin-pe_val_perplexity_history.pt', map_location=device)

post_relu_pe_learned_train_loss = torch.load(cur_dir + 'log/post-ln_relu_learned-pe_train_loss_history.pt', map_location=device)
post_relu_pe_learned_val_loss = torch.load(cur_dir + 'log/post-ln_relu_learned-pe_val_loss_history.pt', map_location=device)
post_relu_pe_learned_train_perplexity = torch.load(cur_dir + 'log/post-ln_relu_learned-pe_train_perplexity_history.pt', map_location=device)
post_relu_pe_learned_val_perplexity = torch.load(cur_dir + 'log/post-ln_relu_learned-pe_val_perplexity_history.pt', map_location=device)

pre_relu_pe_learned_train_loss = torch.load(cur_dir + 'log/pre-ln_relu_learned-pe_train_loss_history.pt', map_location=device)
pre_relu_pe_learned_val_loss = torch.load(cur_dir + 'log/pre-ln_relu_learned-pe_val_loss_history.pt', map_location=device)
pre_relu_pe_learned_train_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_learned-pe_train_perplexity_history.pt', map_location=device)
pre_relu_pe_learned_val_perplexity = torch.load(cur_dir + 'log/pre-ln_relu_learned-pe_val_perplexity_history.pt', map_location=device)

pre_swish_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_swish_sin-pe_train_loss_history.pt', map_location=device)
pre_swish_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_swish_sin-pe_val_loss_history.pt', map_location=device)
pre_swish_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_swish_sin-pe_train_perplexity_history.pt', map_location=device)
pre_swish_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_swish_sin-pe_val_perplexity_history.pt', map_location=device)

pre_ln_ffn_glu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_ffn_glu_sin-pe_train_loss_history.pt', map_location=device)
pre_ln_ffn_glu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_ffn_glu_sin-pe_val_loss_history.pt', map_location=device)
pre_ln_ffn_glu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_glu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_ln_ffn_glu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_glu_sin-pe_val_perplexity_history.pt', map_location=device)

pre_gelu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_gelu_sin-pe_train_loss_history.pt', map_location=device)
pre_gelu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_gelu_sin-pe_val_loss_history.pt', map_location=device)
pre_gelu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_gelu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_gelu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_gelu_sin-pe_val_perplexity_history.pt', map_location=device)


pre_ffn_reglu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_ffn_reglu_sin-pe_train_loss_history.pt', map_location=device)
pre_ffn_reglu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_ffn_reglu_sin-pe_val_loss_history.pt', map_location=device)
pre_ffn_reglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_reglu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_ffn_reglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_reglu_sin-pe_val_perplexity_history.pt', map_location=device)

pre_ffn_geglu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_ffn_geglu_sin-pe_train_loss_history.pt', map_location=device)
pre_ffn_geglu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_ffn_geglu_sin-pe_val_loss_history.pt', map_location=device)
pre_ffn_geglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_geglu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_ffn_geglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_geglu_sin-pe_val_perplexity_history.pt', map_location=device)


pre_ffn_swiglu_pe_sin_train_loss = torch.load(cur_dir + 'log/pre-ln_ffn_swiglu_sin-pe_train_loss_history.pt', map_location=device)
pre_ffn_swiglu_pe_sin_val_loss = torch.load(cur_dir + 'log/pre-ln_ffn_swiglu_sin-pe_val_loss_history.pt', map_location=device)
pre_ffn_swiglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_swiglu_sin-pe_train_perplexity_history.pt', map_location=device)
pre_ffn_swiglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/pre-ln_ffn_swiglu_sin-pe_val_perplexity_history.pt', map_location=device)

# %%
configs_names = {
	'Post-LN + ReLU': {
		'train_loss': post_relu_ne_train_loss,
		'val_loss': post_relu_ne_val_loss,
		'train_ppl': post_relu_ne_train_perplexity,
		'val_ppl': post_relu_ne_val_perplexity
	},
	'Post-LN + GELU': {
		'train_loss': post_gelu_ne_train_loss,
		'val_loss': post_gelu_ne_val_loss,
		'train_ppl': post_gelu_ne_train_perplexity,
		'val_ppl': post_gelu_ne_val_perplexity
	},
	'Post-Ln + GLU': {
		'train_loss': post_glu_ne_train_loss,
		'val_loss': post_glu_ne_val_loss,
		'train_ppl': post_glu_ne_train_perplexity,
		'val_ppl': post_glu_ne_val_perplexity
	},
	'Pre-LN + ReLU': {
		'train_loss': pre_relu_ne_train_loss,
		'val_loss': pre_relu_ne_val_loss,
		'train_ppl': pre_relu_ne_train_perplexity,
		'val_ppl': pre_relu_ne_val_perplexity
	},
	'Pre-LN + GLU' :{
		'train_loss': pre_glu_ne_train_loss,
		'val_loss': pre_glu_ne_val_loss,
		'train_ppl': pre_glu_ne_train_perplexity,
		'val_ppl': pre_glu_ne_val_perplexity
	},
	'Post-LN + ReLU + Positional encoding (sin/cos)': {
		'train_loss': post_relu_pe_sin_train_loss,
		'val_loss': post_relu_pe_sin_val_loss,
		'train_ppl': post_relu_pe_sin_train_perplexity,
		'val_ppl': post_relu_pe_sin_val_perplexity
	},
	'Post-LN + ReLU + Positional encoding (learned)': {
		'train_loss': post_relu_pe_learned_train_loss,
		'val_loss': post_relu_pe_learned_val_loss,
		'train_ppl': post_relu_pe_learned_train_perplexity,
		'val_ppl': post_relu_pe_learned_val_perplexity
	},
	'Pre-LN + ReLU + Positional encoding (sin/cos)': {
		'train_loss': pre_relu_pe_sin_train_loss,
		'val_loss': pre_relu_pe_sin_val_loss,
		'train_ppl': pre_relu_pe_sin_train_perplexity,
		'val_ppl': pre_relu_pe_sin_val_perplexity
	},
	'Pre-LN + ReLU + Positional encoding (learned)': {
		'train_loss': pre_relu_pe_learned_train_loss,
		'val_loss': pre_relu_pe_learned_val_loss,
		'train_ppl': pre_relu_pe_learned_train_perplexity,
		'val_ppl': pre_relu_pe_learned_val_perplexity
	},
	'Pre-LN + GELU + Positional encoding (sin/cos)': {
		'train_loss': pre_gelu_pe_sin_train_loss,
		'val_loss': pre_gelu_pe_sin_val_loss,
		'train_ppl': pre_gelu_pe_sin_train_perplexity,
		'val_ppl': pre_gelu_pe_sin_val_perplexity
	},
    'Pre-LN + SWISH + Positional encoding (sin/cos)': {
		'train_loss': pre_swish_pe_sin_train_loss,
		'val_loss': pre_swish_pe_sin_val_loss,
		'train_ppl': pre_swish_pe_sin_train_perplexity,
		'val_ppl': pre_swish_pe_sin_val_perplexity
	},
	'Pre-LN + GLU + Positional encoding (sin/cos)': {
		'train_loss': pre_glu_pe_sin_train_loss,
		'val_loss': pre_glu_pe_sin_val_loss,
		'train_ppl': pre_glu_pe_sin_train_perplexity,
		'val_ppl': pre_glu_pe_sin_val_perplexity
	},
	'Pre-LN + GLU + Positional encoding (learned)': {
		'train_loss': pre_glu_pe_learned_train_loss,
		'val_loss': pre_glu_pe_learned_val_loss,
		'train_ppl': pre_glu_pe_learned_train_perplexity,
		'val_ppl': pre_glu_pe_learned_val_perplexity
	},
	'Pre-LN + FFN-GLU + Positional encoding (sin/cos)': {
		'train_loss': pre_ln_ffn_glu_pe_sin_train_loss,
		'val_loss': pre_ln_ffn_glu_pe_sin_val_loss,
		'train_ppl': pre_ln_ffn_glu_pe_sin_train_perplexity,
		'val_ppl': pre_ln_ffn_glu_pe_sin_val_perplexity
	},
	'Pre-LN + FFN-ReGLU + Positional encoding (sin/cos)': {
		'train_loss': pre_ffn_reglu_pe_sin_train_loss,
		'val_loss': pre_ffn_reglu_pe_sin_val_loss,
		'train_ppl': pre_ffn_reglu_pe_sin_train_perplexity,
		'val_ppl': pre_ffn_reglu_pe_sin_val_perplexity
	},
	'Pre-LN + FFF-GEGLU + Positional encoding (sin/cos)': {
		'train_loss': pre_ffn_geglu_pe_sin_train_loss,
		'val_loss': pre_ffn_geglu_pe_sin_val_loss,
		'train_ppl': pre_ffn_geglu_pe_sin_train_perplexity,
		'val_ppl': pre_ffn_geglu_pe_sin_val_perplexity
	},
    'Pre-LN + FFN-SwiGLU + Positional encoding (sin/cos)': {
		'train_loss': pre_ffn_swiglu_pe_sin_train_loss,
		'val_loss': pre_ffn_swiglu_pe_sin_val_loss,
		'train_ppl': pre_ffn_swiglu_pe_sin_train_perplexity,
		'val_ppl': pre_ffn_swiglu_pe_sin_val_perplexity
	}
}

# %%
comparison_data = []
for name, metrics in configs_names.items():
	comparison_data.append({
		'Config': name,
		'Final Train Loss': f'{metrics['train_loss'][-1].item():.4f}',
		'Final Val Loss': f'{metrics['val_loss'][-1].item():.4f}',
		'Final Train PPL': f'{metrics['train_ppl'][-1].item():.4f}',
		'Final Val PPL': f'{metrics['val_ppl'][-1].item():.4f}',
		'Best Val Loss': f'{min(metrics['val_loss']).item():.4f}',
		'Best Val PPL': f'{min(metrics['val_ppl']).item():.4f}'
	})

df = pd.DataFrame(comparison_data)
print(df.to_string(index=False))
# Out:
#                                              Config Final Train Loss Final Val Loss Final Train PPL Final Val PPL Best Val Loss Best Val PPL
#                                      Post-LN + ReLU           2.2356         2.2233          9.3516        9.2375        2.2226       9.2312
#                                      Post-LN + GELU           2.2349         2.2232          9.3456        9.2372        2.2232       9.2372
#                                       Post-Ln + GLU           2.2368         2.2274          9.3631        9.2760        2.2274       9.2760
#                                       Pre-LN + ReLU           2.2576         2.2305          9.5603        9.3043        2.2305       9.3043
#                                        Pre-LN + GLU           2.2753         2.2433          9.7311        9.4244        2.2433       9.4244
# ...

# %%
poetry_post_relu_sin_pe_train_loss = torch.load(cur_dir + 'log/poetry_post-ln_relu_sin-pe_train_loss_history.pt', map_location=device)
poetry_post_relu_sin_pe_val_loss = torch.load(cur_dir + 'log/poetry_post-ln_relu_sin-pe_val_loss_history.pt', map_location=device)
poetry_post_relu_sin_pe_train_perplexity = torch.load(cur_dir + 'log/poetry_post-ln_relu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_post_relu_sin_pe_val_perplexity = torch.load(cur_dir + 'log/poetry_post-ln_relu_sin-pe_val_perplexity_history.pt', map_location=device)


poetry_pre_relu_sin_pe_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_relu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_relu_sin_pe_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_relu_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_relu_sin_pe_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_relu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_relu_sin_pe_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_relu_sin-pe_val_perplexity_history.pt', map_location=device)


poetry_pre_gelu_sin_pe_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_gelu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_gelu_sin_pe_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_gelu_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_gelu_sin_pe_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_gelu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_gelu_sin_pe_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_gelu_sin-pe_val_perplexity_history.pt', map_location=device)


poetry_pre_swish_pe_sin_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_swish_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_swish_pe_sin_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_swish_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_swish_pe_sin_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_swish_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_swish_pe_sin_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_swish_sin-pe_val_perplexity_history.pt', map_location=device)

poetry_pre_glu_sin_pe_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_glu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_glu_sin_pe_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_glu_sin-pe_val_loss_history.pt', map_location=device)	
poetry_pre_glu_sin_pe_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_glu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_glu_sin_pe_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_glu_sin-pe_val_perplexity_history.pt', map_location=device)


poetry_pre_ffn_reglu_pe_sin_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_reglu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_ffn_reglu_pe_sin_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_reglu_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_ffn_reglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_reglu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_ffn_reglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_reglu_sin-pe_val_perplexity_history.pt', map_location=device)

poetry_pre_ffn_geglu_pe_sin_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_geglu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_ffn_geglu_pe_sin_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_geglu_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_ffn_geglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_geglu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_ffn_geglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_geglu_sin-pe_val_perplexity_history.pt', map_location=device)


poetry_pre_swiglu_pe_sin_train_loss = torch.load(cur_dir + 'log/poetry_pre-ln_swiglu_sin-pe_train_loss_history.pt', map_location=device)
poetry_pre_swiglu_pe_sin_val_loss = torch.load(cur_dir + 'log/poetry_pre-ln_swiglu_sin-pe_val_loss_history.pt', map_location=device)
poetry_pre_swiglu_pe_sin_train_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_swiglu_sin-pe_train_perplexity_history.pt', map_location=device)
poetry_pre_swiglu_pe_sin_val_perplexity = torch.load(cur_dir + 'log/poetry_pre-ln_swiglu_sin-pe_val_perplexity_history.pt', map_location=device)

# %%
configs_poetry = {
	'Post-LN + ReLU + Positional encoding (sin/cos)': {
		'train_loss': poetry_post_relu_sin_pe_train_loss,
		'val_loss': poetry_post_relu_sin_pe_val_loss,
		'train_ppl': poetry_post_relu_sin_pe_train_perplexity,
		'val_ppl': poetry_post_relu_sin_pe_val_perplexity
	},
	'Pre-LN + ReLU + Positional encoding (sin/cos)': {
		'train_loss': poetry_pre_relu_sin_pe_train_loss,
		'val_loss': poetry_pre_relu_sin_pe_val_loss,
		'train_ppl': poetry_pre_relu_sin_pe_train_perplexity,
		'val_ppl': poetry_pre_relu_sin_pe_val_perplexity
	},
	'Pre-LN + GELU + Positional encoding (sin/cos)': {
		'train_loss': poetry_pre_gelu_sin_pe_train_loss,
		'val_loss': poetry_pre_gelu_sin_pe_val_loss,
		'train_ppl': poetry_pre_gelu_sin_pe_train_perplexity,
		'val_ppl': poetry_pre_gelu_sin_pe_val_perplexity
	},
    'Pre-LN + SWISH + Positional encoding (sin/cos)': {
		'train_loss': poetry_pre_swish_pe_sin_train_loss,
		'val_loss': poetry_pre_swish_pe_sin_val_loss,
		'train_ppl': poetry_pre_swish_pe_sin_train_perplexity,
		'val_ppl': poetry_pre_swish_pe_sin_val_perplexity
	},
	'Pre-LN + GLU + Positional encoding (sin/cos)': {
		'train_loss': poetry_pre_glu_sin_pe_train_loss,
		'val_loss': poetry_pre_glu_sin_pe_val_loss,
		'train_ppl': poetry_pre_glu_sin_pe_train_perplexity,
		'val_ppl': poetry_pre_glu_sin_pe_val_perplexity
	},
	'Pre-LN + FFN-ReGLU + Positional encoding (sin/cos)': {
	    'train_loss': poetry_pre_ffn_reglu_pe_sin_train_loss,
		'val_loss': poetry_pre_ffn_reglu_pe_sin_val_loss,
	    'train_ppl': poetry_pre_ffn_reglu_pe_sin_train_perplexity,
		'val_ppl': poetry_pre_ffn_reglu_pe_sin_val_perplexity
	},
	'Pre-LN + FFF-GEGLU + Positional encoding (sin/cos)': {
	    'train_loss': poetry_pre_ffn_geglu_pe_sin_train_loss,
		'val_loss': poetry_pre_ffn_geglu_pe_sin_val_loss,
		'train_ppl': poetry_pre_ffn_geglu_pe_sin_train_perplexity,
	    'val_ppl': poetry_pre_ffn_geglu_pe_sin_val_perplexity
	},
    'Pre-LN + FFN-SwiGLU + Positional encoding (sin/cos)': {
        'train_loss': poetry_pre_swiglu_pe_sin_train_loss,
        'val_loss': poetry_pre_swiglu_pe_sin_val_loss,
        'train_ppl': poetry_pre_swiglu_pe_sin_train_perplexity,
		'val_ppl': poetry_pre_swiglu_pe_sin_val_perplexity
	}
}

# %%
comparison_data = []
for name, metrics in configs_poetry.items():
	comparison_data.append({
		'Config': name,
		'Final Train Loss': f'{metrics['train_loss'][-1].item():.4f}',
		'Final Val Loss': f'{metrics['val_loss'][-1].item():.4f}',
		'Final Train PPL': f'{metrics['train_ppl'][-1].item():.4f}',
		'Final Val PPL': f'{metrics['val_ppl'][-1].item():.4f}',
		'Best Val Loss': f'{min(metrics['val_loss']).item():.4f}',
		'Best Val PPL': f'{min(metrics['val_ppl']).item():.4f}'
	})

df = pd.DataFrame(comparison_data)
print(df.to_string(index=False))
# Out:
#                                              Config Final Train Loss Final Val Loss Final Train PPL Final Val PPL Best Val Loss Best Val PPL
#      Post-LN + ReLU + Positional encoding (sin/cos)           4.0291         4.4271         56.2120       83.6913        4.4271      83.6913
#       Pre-LN + ReLU + Positional encoding (sin/cos)           4.6207         4.6835        101.5652      108.1518        4.6835     108.1518
#       Pre-LN + GELU + Positional encoding (sin/cos)           4.5897         4.6620         98.4641      105.8477        4.6620     105.8477
#      Pre-LN + SWISH + Positional encoding (sin/cos)           4.5920         4.6606         98.6891      105.7046        4.6606     105.7046
#        Pre-LN + GLU + Positional encoding (sin/cos)           4.6462         4.7037        104.1915      110.3502        4.7037     110.3502
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

for name, metrics in configs_names.items():
	axes[0].plot(np.arange(len(metrics['val_ppl'])) + 1, metrics['val_ppl'].cpu(), label=f'{name}', alpha=0.7)

for name, metrics in configs_poetry.items():
	axes[1].plot(np.arange(len(metrics['val_ppl'])) + 1, metrics['val_ppl'].cpu(), label=f'{name}', alpha=0.7)

axes[0].set_title('Names (Validation Perplexity)')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Perplexity')
axes[0].legend()
axes[0].grid(alpha=0.3)

axes[1].set_title('Poetry (Validation Perplexity )')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Perplexity')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()
